# %%
from magnet.ron import milvus
config = {
    "MILVUS_URI": "192.168.2.69"
    , "DIMENSION": 1024
    , "MODEL": "BAAI/bge-large-en-v1.5"
    , "INDEX": "test_collection"
    , "INDEX_PARAMS": {
        'metric_type': 'COSINE',
        'index_type':'HNSW',
        'params': {
            "efConstruction": 40
            , "M": 48
        },
    }
}

index = milvus.Embedder(config)
results = index.search({'text':'financial'})
print(results)
index.delete()
# Out:
# 🌊 SUCCESS: connected successfully to 192.168.2.69
# [{'text': 'tion: value: 26115ownershipNature: directOrIndirectOwnership: value: DderivativeTable: derivativeTransaction: securityTitle: value: Restricted Stock UnitsconversionOrExercisePrice: transactionDate: value: 20231013transactionCoding: transactionFormTyp', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5883305668830872}, {'text': 'tion: value: 26115ownershipNature: directOrIndirectOwnership: value: DderivativeTable: derivativeTransaction: securityTitle: value: Restricted Stock UnitsconversionOrExercisePrice: transactionDate: value: 20231013transactionCoding: transactionFormTyp', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5883305668830872}, {'text': 'tion: value: 26115ownershipNature: directOrIndirectOwnership: value: DderivativeTable: derivativeTransaction: securityTitle: value: Restricted Stock UnitsconversionOrExercisePrice: transactionDate: value: 20231013transactionCoding: transactionFormTyp', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5883305668830872}, {'text': 'tion: value: 26115ownershipNature: directOrIndirectOwnership: value: DderivativeTable: derivativeTransaction: securityTitle: value: Restricted Stock UnitsconversionOrExercisePrice: transactionDate: value: 20231013transactionCoding: transactionFormTyp', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5883305668830872}, {'text': 'tion: value: 26115ownershipNature: directOrIndirectOwnership: value: DderivativeTable: derivativeTransaction: securityTitle: value: Restricted Stock UnitsconversionOrExercisePrice: transactionDate: value: 20231013transactionCoding: transactionFormTyp', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5883305668830872}, {'text': 'rposes.footnote: The restricted stock units are fully vested.ownerSignature: signatureName: /s/ Rosemary L. Klein, AttorneyinFactsignatureDate: 20231016', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5825729966163635}, {'text': 'rposes.footnote: The restricted stock units are fully vested.ownerSignature: signatureName: /s/ Rosemary L. Klein, AttorneyinFactsignatureDate: 20231016', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5825729966163635}, {'text': 'rposes.footnote: The restricted stock units are fully vested.ownerSignature: signatureName: /s/ Rosemary L. Klein, AttorneyinFactsignatureDate: 20231016', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5825729966163635}, {'text': 'rposes.footnote: The restricted stock units are fully vested.ownerSignature: signatureName: /s/ Rosemary L. Klein, AttorneyinFactsignatureDate: 20231016', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5825729966163635}, {'text': 'rposes.footnote: The restricted stock units are fully vested.ownerSignature: signatureName: /s/ Rosemary L. Klein, AttorneyinFactsignatureDate: 20231016', 'document': '4 - Giljum Matthew C. (0001809723) (Reporting)_doc4', 'distance': 0.5825729966163635}, {'text': 'below will take a few moments Periods Measures Axis Explicit Typed Members Explicit Typed Scale Balance 2 Debit Credit Reset AllFilters Links Facts Loading Inline Form Tagged Sections Search in All Search in InternalSections Only Search in ExternalSe', 'document': '8-K - NNN REIT, INC. (0000751364) (Filer)_nnn-20231101', 'distance': 0.5810803771018982}, {'text': 'below will take a few moments Periods Measures Axis Explicit Typed Members Explicit Typed Scale Balance 2 Debit Credit Reset AllFilters Links Facts Loading Inline Form Tagged Sections Search in All Search in InternalSections Only Search in ExternalSe', 'document': '8-K - NNN REIT, INC. (0000751364) (Filer)_nnn-20231101', 'distance': 0.5810803771018982}, {'text': 'below will take a few moments Periods Measures Axis Explicit Typed Members Explicit Typed Scale Balance 2 Debit Credi ...
# 🚨 WARN: test_collection deleted
